# %% [markdown]
# Importing all the necessary libraries for the project

# %%
#import the libraries requires for project
import numpy as np
import pandas as pd
import os
os.getcwd()
# Out:
# 'C:\\Users\\Siddhesh'

# %% [markdown]
# Read from CSV file and display the details of first 5 rows

# %%
#read from csv file and display all 26 coulmns in DF
df = pd.read_csv('Automobile_data.csv')
pd.set_option('display.max_columns', 26)
pd.set_option('display.max_rows', 210)
df.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %% [markdown]
# Importing the necessary libraries for Panda profiling

# %%
import pandas_profiling
import collections
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# Pandas profiling to do variable analysis and output extracted in html

# %%
eda_analysis = pandas_profiling.ProfileReport(df)
eda_analysis.to_file('autoproject_analysis.html')

# %% [markdown]
# The following command will provide the analysis on mean, std , 25, 75 percentile values on the dataframe columns

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
df.describe(include = 'all')
# Out:
#          symboling normalized-losses    make fuel-type aspiration  \
# count   205.000000               205     205       205        205
# unique         NaN                52      22         2          2
# top            NaN                 ?  toyota       gas        std
# freq           NaN                41      32       185        168
# mean      0.834146               NaN     NaN       NaN        NaN
# std       1.245307               NaN     NaN       NaN        NaN
# min      -2.000000               NaN     NaN       NaN        NaN
# 25%       0.000000               NaN     NaN       NaN        NaN
# 50%       1.000000               NaN     NaN       NaN        NaN
# 75%       2.000000               NaN     NaN       NaN        NaN
# max       3.000000               NaN     NaN       NaN        NaN
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  \
# count           205        205          205             205  205.000000
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.nunique()
# Out:
# symboling              6
# normalized-losses     52
# make                  22
# fuel-type              2
# aspiration             2
# num-of-doors           3
# body-style             5
# drive-wheels           3
# engine-location        2
# wheel-base            53
# length                75
# width                 44
# height                49
# curb-weight          171
# engine-type            7
# num-of-cylinders       7
# engine-size           44
# fuel-system            8
# bore                  39
# stroke                37
# compression-ratio     32
# horsepower            60
# peak-rpm              24
# city-mpg              29
# highway-mpg           30
# price                187
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %% [markdown]
# Dataframe df is stored in clean_df

# %%
clean_df = df
clean_df
# Out:
#      symboling normalized-losses           make fuel-type aspiration  \
# 0            3                 ?    alfa-romero       gas        std
# 1            3                 ?    alfa-romero       gas        std
# 2            1                 ?    alfa-romero       gas        std
# 3            2               164           audi       gas        std
# 4            2               164           audi       gas        std
# 5            2                 ?           audi       gas        std
# 6            1               158           audi       gas        std
# 7            1                 ?           audi       gas        std
# 8            1               158           audi       gas      turbo
# 9            0                 ?           audi       gas      turbo
# 10           2               192            bmw       gas        std
# 11           0               192            bmw       gas        std
# 12           0               188            bmw       gas        std
# ...

# %%
# categorical column value replaced based on another column value
doors = clean_df.loc[clean_df['num-of-doors'] == '?', 'num-of-cylinders'].iloc[0]

# %%
doors
# Out:
# 'four'

# %%
clean_df['num-of-doors'] = clean_df['num-of-doors'].replace('?',doors).astype(str)

# %%
clean_df['num-of-cylinders'].value_counts().plot(kind='bar',color='orange')

# %%
clean_df['body-style'].value_counts().plot(kind='bar',color='maroon')

# %%
clean_df['drive-wheels'].value_counts().plot(kind='bar',color='gold')

# %% [markdown]
# Bogus variable ? is replaced and object is converted to string

# %%
clean_df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
#replace all bogus ? values with NaN
clean_df = clean_df.replace('?',np.NaN)

# %%
clean_df = clean_df.fillna(0)

# %% [markdown]
# Converting object datatype to numeric values

# %%
clean_df["normalized-losses"] = pd.to_numeric(clean_df["normalized-losses"],errors='coerce')

# %%
clean_df["bore"] = pd.to_numeric(clean_df["bore"],errors='coerce')

# %%
clean_df["stroke"] = pd.to_numeric(clean_df["stroke"],errors='coerce')

# %%
clean_df["peak-rpm"] = pd.to_numeric(clean_df["peak-rpm"],errors='coerce')

# %%
clean_df["horsepower"] =  pd.to_numeric(clean_df["horsepower"],errors='coerce')

# %%
clean_df["price"] = pd.to_numeric(clean_df["price"],errors='coerce')

# %%
#before replacing with median values
clean_df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         205.000000  205.000000  205.000000  205.000000
# mean     0.834146          97.600000   98.756585  174.049268   65.907805
# std      1.245307          58.282073    6.021776   12.337289    2.145204
# min     -2.000000           0.000000   86.600000  141.100000   60.300000
# 25%      0.000000          77.000000   94.500000  166.300000   64.100000
# 50%      1.000000         103.000000   97.000000  173.200000   65.500000
# 75%      2.000000         137.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  205.000000   205.000000   205.000000  205.000000  205.000000
# mean    53.724878  2555.565854   126.907317    3.264780    3.191902
# std      2.443522   520.680204    41.642693    0.535268    0.549625
# ...

# %% [markdown]
# The above converted columns with 0 values are replaced with median with below comments

# %%
clean_df["normalized-losses"] = clean_df["normalized-losses"].replace(0,clean_df["normalized-losses"].median())

# %%
clean_df["bore"] = clean_df["bore"].replace(0,clean_df["bore"].median())

# %%
clean_df["stroke"] = clean_df["stroke"].replace(0,clean_df["stroke"].median())

# %%
clean_df["peak-rpm"] = clean_df["peak-rpm"].replace(0,clean_df["peak-rpm"].median())

# %%
clean_df["horsepower"] = clean_df["horsepower"].replace(0,clean_df["horsepower"].median())

# %%
clean_df["price"] = clean_df["price"].replace(0,clean_df["price"].median())

# %%
clean_df.to_excel("output.xlsx",sheet_name='Sheet_name_1')

# %%
df_with_ol = clean_df

# %%
auto_df_median = clean_df.median()
auto_df_median
# Out:
# symboling                1.00
# normalized-losses      103.00
# wheel-base              97.00
# length                 173.20
# width                   65.50
# height                  54.10
# curb-weight           2414.00
# engine-size            120.00
# bore                     3.31
# stroke                   3.29
# compression-ratio        9.00
# horsepower              95.00
# peak-rpm              5200.00
# city-mpg                24.00
# highway-mpg             30.00
# price                10198.00
# dtype: float64

# %%
auto_df_mean = clean_df.mean()
auto_df_mean
# legth, width, wheel-base, engine-size, compression-ratio, highway-mpg
# Out:
# symboling                0.834146
# normalized-losses      118.200000
# wheel-base              98.756585
# length                 174.049268
# width                   65.907805
# height                  53.724878
# curb-weight           2555.565854
# engine-size            126.907317
# bore                     3.329366
# stroke                   3.256098
# compression-ratio       10.142537
# horsepower             104.165854
# peak-rpm              5126.097561
# city-mpg                25.219512
# highway-mpg             30.751220
# price                13148.414634
# dtype: float64

# %%
correlation = clean_df.corr()
correlation
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.436688   -0.531954 -0.357612
# normalized-losses   0.436688           1.000000   -0.101080 -0.050129
# wheel-base         -0.531954          -0.101080    1.000000  0.874587
# length             -0.357612          -0.050129    0.874587  1.000000
# width              -0.232919           0.014333    0.795144  0.841118
# height             -0.541038          -0.350932    0.589435  0.491029
# curb-weight        -0.227691           0.007483    0.776386  0.877728
# engine-size        -0.105790           0.007170    0.569329  0.683360
# bore               -0.132563          -0.082721    0.489556  0.607016
# stroke             -0.004928           0.029101    0.159684  0.128622
# compression-ratio  -0.178515          -0.113189    0.249786  0.158414
# horsepower          0.071064           0.103365    0.352876  0.553337
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
#to select all numerical variables
clean_df_num = clean_df.select_dtypes(include=['float64','int64'])
clean_df_num.head()
# Out:
#    symboling  normalized-losses  wheel-base  length  width  height  \
# 0          3                103        88.6   168.8   64.1    48.8
# 1          3                103        88.6   168.8   64.1    48.8
# 2          1                103        94.5   171.2   65.5    52.4
# 3          2                164        99.8   176.6   66.2    54.3
# 4          2                164        99.4   176.6   66.4    54.3
#
#    curb-weight  engine-size  bore  stroke  compression-ratio  horsepower  \
# 0         2548          130  3.47    2.68                9.0         111
# 1         2548          130  3.47    2.68                9.0         111
# 2         2823          152  2.68    3.47                9.0         154
# 3         2337          109  3.19    3.40               10.0         102
# 4         2824          136  3.19    3.40                8.0         115
#
#    peak-rpm  city-mpg  highway-mpg  price
# 0      5000        21           27  13495
# ...

# %% [markdown]
# Ploting Histogram for numerical variable

# %%
clean_df_num.hist(bins = 20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000205D89E8DD8>,
# ...
#       dtype=object)

# %% [markdown]
# Visualizing the correlation of price variable with other numerical variable

# %%
#correlation of other variable with price usinf pairplot
for i in range(0, len(clean_df_num.columns),16):
    plt.rcParams['figure.figsize']=(25,20)
   # sns.pairplot(clean_df_num, y_vars = ["price"], x_vars = clean_df_num.columns[i:i+16])   
    sns.pairplot(clean_df_num, y_vars = ["price"], x_vars = clean_df_num.columns[i:i+8], diag_kind = 'kde', plot_kws = {'alpha': 1.0, 's': 100, 'edgecolor': 'k'})
    sns.pairplot(clean_df_num, y_vars = ["price"], x_vars = clean_df_num.columns[i+9:i+16], diag_kind = 'kde', plot_kws = {'alpha': 1.0, 's': 100, 'edgecolor': 'k'})

# %% [markdown]
# Find Correlation among numerical variables

# %%
corr_num = clean_df_num.corr()
corr_num
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.436688   -0.531954 -0.357612
# normalized-losses   0.436688           1.000000   -0.101080 -0.050129
# wheel-base         -0.531954          -0.101080    1.000000  0.874587
# length             -0.357612          -0.050129    0.874587  1.000000
# width              -0.232919           0.014333    0.795144  0.841118
# height             -0.541038          -0.350932    0.589435  0.491029
# curb-weight        -0.227691           0.007483    0.776386  0.877728
# engine-size        -0.105790           0.007170    0.569329  0.683360
# bore               -0.132563          -0.082721    0.489556  0.607016
# stroke             -0.004928           0.029101    0.159684  0.128622
# compression-ratio  -0.178515          -0.113189    0.249786  0.158414
# horsepower          0.071064           0.103365    0.352876  0.553337
# ...

# %%
from scipy import stats

# %%
Q1 = clean_df.quantile(0.25)
Q3 = clean_df.quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# symboling               2.00
# normalized-losses      36.00
# wheel-base              7.90
# length                 16.80
# width                   2.80
# height                  3.50
# curb-weight           790.00
# engine-size            44.00
# bore                    0.43
# stroke                  0.30
# compression-ratio       0.80
# horsepower             46.00
# peak-rpm              700.00
# city-mpg               11.00
# highway-mpg             9.00
# price                8712.00
# dtype: float64

# %%
lower_bound = abs(Q1 - (IQR * 1.5))
upper_bound = abs(Q3 + (IQR * 1.5))

# %%
lower_bound
# Out:
# symboling               3.000
# normalized-losses      47.000
# wheel-base             82.650
# length                141.100
# width                  59.900
# height                 46.750
# curb-weight           960.000
# engine-size            31.000
# bore                    2.505
# stroke                  2.660
# compression-ratio       7.400
# horsepower              1.000
# peak-rpm             3750.000
# city-mpg                2.500
# highway-mpg            11.500
# price                5280.000
# dtype: float64

# %%
upper_bound
# Out:
# symboling                5.000
# normalized-losses      191.000
# wheel-base             114.250
# length                 208.300
# width                   71.100
# height                  60.750
# curb-weight           4120.000
# engine-size            207.000
# bore                     4.225
# stroke                   3.860
# compression-ratio       10.600
# horsepower             185.000
# peak-rpm              6550.000
# city-mpg                46.500
# highway-mpg             47.500
# price                29568.000
# dtype: float64

# %%
clean_df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000          205.00000  205.000000  205.000000  205.000000
# mean     0.834146          118.20000   98.756585  174.049268   65.907805
# std      1.245307           32.58419    6.021776   12.337289    2.145204
# min     -2.000000           65.00000   86.600000  141.100000   60.300000
# 25%      0.000000          101.00000   94.500000  166.300000   64.100000
# 50%      1.000000          103.00000   97.000000  173.200000   65.500000
# 75%      2.000000          137.00000  102.400000  183.100000   66.900000
# max      3.000000          256.00000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  205.000000   205.000000   205.000000  205.000000  205.000000
# mean    53.724878  2555.565854   126.907317    3.329366    3.256098
# std      2.443522   520.680204    41.642693    0.270858    0.313634
# ...

# %% [markdown]
# Detecting and treating outliers

# %%
 plt.rcParams['figure.figsize']=(20,6)
sns.boxplot(clean_df["price"])

# %%
(clean_df["price"] > upper_bound["price"]) | (clean_df["price"] < abs(lower_bound["price"]))
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15      True
# 16      True
# 17      True
# 18      True
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47      True
# 48      True
# 49      True
# 50      True
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
clean_df["price"] = np.where((clean_df["price"] > upper_bound["price"]) | (clean_df["price"] < abs(lower_bound["price"])),clean_df["price"].mean(),clean_df["price"])

# %%
sns.boxplot(clean_df["price"])

# %%
sns.boxplot(clean_df["wheel-base"])

# %%
clean_df["wheel-base"] = np.where((clean_df["wheel-base"] > 99) | (clean_df["wheel-base"] < 92),clean_df["wheel-base"].median(),clean_df["wheel-base"])

# %%
sns.boxplot(clean_df["wheel-base"])

# %%
#outlier detected df  --   nl
clean_df["normalized-losses"] = np.where((clean_df["normalized-losses"] > 180 ) | (clean_df["normalized-losses"] < lower_bound["normalized-losses"]),clean_df["normalized-losses"].mean(),clean_df["normalized-losses"])

# %%
sns.boxplot(clean_df["normalized-losses"])

# %%
clean_df["bore"] = np.where((clean_df["bore"] > upper_bound["bore"]) | (clean_df["bore"] < lower_bound["bore"]),clean_df["bore"].median(),clean_df["bore"])

# %%
sns.boxplot(clean_df["bore"])

# %%
clean_df["stroke"] = np.where((clean_df["stroke"] > 3.6) | (clean_df["stroke"] < 2.9),clean_df["stroke"].median(),clean_df["stroke"])

# %%
sns.boxplot(clean_df["stroke"])

# %%
clean_df["peak-rpm"] = np.where((clean_df["peak-rpm"] > upper_bound["peak-rpm"]) | (clean_df["peak-rpm"] < lower_bound["peak-rpm"]),clean_df["peak-rpm"].mean(),clean_df["peak-rpm"])

# %%
sns.boxplot(clean_df["peak-rpm"])

# %%
clean_df["horsepower"] = np.where((clean_df["horsepower"] > upper_bound["horsepower"]) | (clean_df["horsepower"] < lower_bound["horsepower"]),clean_df["horsepower"].mean(),clean_df["horsepower"])

# %%
sns.boxplot(clean_df["horsepower"])

# %%
#clean_df["symboling"] = np.where((clean_df["symboling"] > upper_bound["symboling"]) | (clean_df["symboling"] < lower_bound["symboling"]),clean_df["symboling"].mean(),clean_df["symboling"])

# %%
sns.boxplot(clean_df["symboling"])

# %%
clean_df["length"] = np.where((clean_df["length"] > 200) | (clean_df["length"] < 150),clean_df["length"].mean(),clean_df["length"])

# %%
sns.boxplot(clean_df["length"])

# %%
clean_df["width"] = np.where((clean_df["width"] > 67) | (clean_df["width"] < 62),clean_df["width"].mean(),clean_df["width"])

# %%
sns.boxplot(clean_df["width"])

# %%
clean_df["height"] = np.where((clean_df["height"] > upper_bound["height"]) | (clean_df["height"] < lower_bound["height"]),clean_df["height"].median(),clean_df["height"])

# %%
sns.boxplot(clean_df["height"])

# %%
clean_df["curb-weight"] = np.where((clean_df["curb-weight"] > upper_bound["curb-weight"]) | (clean_df["curb-weight"] < lower_bound["curb-weight"]),clean_df["curb-weight"].mean(),clean_df["curb-weight"])

# %%
sns.boxplot(clean_df["curb-weight"])

# %%
clean_df["engine-size"] = np.where((clean_df["engine-size"] > 190) | (clean_df["engine-size"] < lower_bound["engine-size"]),clean_df["engine-size"].mean(),clean_df["engine-size"])

# %%
sns.boxplot(clean_df["engine-size"])

# %%
clean_df["compression-ratio"] = np.where((clean_df["compression-ratio"] > 9.6) | (clean_df["compression-ratio"] < 8.6),clean_df["compression-ratio"].mean(),clean_df["compression-ratio"])

# %%
sns.boxplot(clean_df["compression-ratio"])

# %%
clean_df["city-mpg"] = np.where((clean_df["city-mpg"] > upper_bound["city-mpg"]) | (clean_df["city-mpg"] < lower_bound["city-mpg"]),clean_df["city-mpg"].median(),clean_df["city-mpg"])

# %%
sns.boxplot(clean_df["city-mpg"])

# %%
clean_df["highway-mpg"] = np.where((clean_df["highway-mpg"] > 46) | (clean_df["highway-mpg"] < lower_bound["highway-mpg"]),clean_df["highway-mpg"].median(),clean_df["highway-mpg"])

# %%
sns.boxplot(clean_df["highway-mpg"])

# %%
clean_df_num_o = clean_df.select_dtypes(include=['float64','int64'])
clean_df_num_o.head()
# Out:
#    symboling  normalized-losses  wheel-base  length  width  height  \
# 0          3              103.0        97.0   168.8   64.1    48.8
# 1          3              103.0        97.0   168.8   64.1    48.8
# 2          1              103.0        94.5   171.2   65.5    52.4
# 3          2              164.0        97.0   176.6   66.2    54.3
# 4          2              164.0        97.0   176.6   66.4    54.3
#
#    curb-weight  engine-size  bore  stroke  compression-ratio  horsepower  \
# 0       2548.0        130.0  3.47    3.29           9.000000       111.0
# 1       2548.0        130.0  3.47    3.29           9.000000       111.0
# 2       2823.0        152.0  2.68    3.47           9.000000       154.0
# 3       2337.0        109.0  3.19    3.40          10.142537       102.0
# 4       2824.0        136.0  3.19    3.40          10.142537       115.0
#
#    peak-rpm  city-mpg  highway-mpg    price
# 0    5000.0      21.0         27.0  13495.0
# ...

# %%
#correlation of other variable with price usinf pairplot after cleaning

for i in range(0, len(clean_df_num_o.columns),16):
    plt.rcParams['figure.figsize']=(25,20)
   # sns.pairplot(clean_df_num, y_vars = ["price"], x_vars = clean_df_num.columns[i:i+16])   
    sns.pairplot(clean_df_num_o, y_vars = ["price"], x_vars = clean_df_num_o.columns[i:i+8], diag_kind = 'kde', plot_kws = {'alpha': 1.0, 's': 100, 'edgecolor': 'k'})
    sns.pairplot(clean_df_num_o, y_vars = ["price"], x_vars = clean_df_num_o.columns[i+9:i+16], diag_kind = 'kde', plot_kws = {'alpha': 1.0, 's': 100, 'edgecolor': 'k'})

# %%
print(clean_df["price"].describe())
plt.figure(figsize=(9, 8))
sns.distplot(clean_df["price"],  bins=20, hist= True, kde = False, rug = False);
# Out:
# count      205.000000
# mean     11707.049018
# std       4715.000260
# min       5348.000000
# 25%       7898.000000
# 50%      10345.000000
# 75%      13950.000000
# max      28248.000000
# Name: price, dtype: float64

# %%
automobile_df = clean_df

# %%
automobile_df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         205.000000  205.000000  205.000000  205.000000
# mean     0.834146         113.737561   96.183415  174.052662   65.227719
# std      1.245307          25.403983    1.418200   11.167323    1.026537
# min     -2.000000          65.000000   93.000000  150.000000   62.500000
# 25%      0.000000         101.000000   95.300000  167.300000   64.200000
# 50%      1.000000         103.000000   97.000000  173.200000   65.500000
# 75%      2.000000         128.000000   97.000000  180.300000   65.907805
# max      3.000000         168.000000   98.800000  199.600000   66.900000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  205.000000   205.000000   205.000000  205.000000  205.000000
# mean    53.724878  2555.565854   119.310744    3.329366    3.290390
# std      2.443522   520.680204    26.319545    0.270858    0.150531
# ...

# %%
plt.rcParams['figure.figsize']=(23,10)
plt.title("Make Versus Price")
ax = sns.boxplot(x="make", y="price", data=automobile_df)

# %%
pd.crosstab(index=automobile_df["make"],columns="Frequency")
# Out:
# col_0          Frequency
# make
# alfa-romero            3
# audi                   7
# bmw                    8
# chevrolet              3
# dodge                  9
# honda                 13
# isuzu                  4
# jaguar                 3
# mazda                 17
# mercedes-benz          8
# mercury                1
# mitsubishi            13
# nissan                18
# peugot                11
# plymouth               7
# porsche                5
# renault                2
# saab                   6
# subaru                12
# toyota                32
# volkswagen            12
# volvo                 11

# %%
pd.crosstab(index=automobile_df["num-of-doors"],columns="Frequency")
# Out:
# col_0         Frequency
# num-of-doors
# four                116
# two                  89

# %%
pd.crosstab(index=automobile_df["drive-wheels"],columns="Frequency")
# Out:
# col_0         Frequency
# drive-wheels
# 4wd                   9
# fwd                 120
# rwd                  76

# %%
automobile_df.head(10)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              103.0  alfa-romero       gas        std
# 1          3              103.0  alfa-romero       gas        std
# 2          1              103.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
# 5          2              103.0         audi       gas        std
# 6          1              158.0         audi       gas        std
# 7          1              103.0         audi       gas        std
# 8          1              158.0         audi       gas      turbo
# 9          0              103.0         audi       gas      turbo
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        97.0   168.8
# 1          two  convertible          rwd           front        97.0   168.8
# ...

# %%
plt.rcParams['figure.figsize']=(23,10)
plt.title("Drive wheels Versus Price")
ax = sns.boxplot( x="drive-wheels", y="price", data = automobile_df)

# %%
plt.rcParams['figure.figsize']=(23,10)
plt.title("Drive wheels Versus Milege")
ax = sns.boxplot( x="drive-wheels", y="city-mpg", data = automobile_df)

# %%
new_df_group = automobile_df.groupby('peak-rpm').agg({'horsepower':[np.size,np.mean]})
new_df_group.head(10)
# Out:
#          horsepower
#                size        mean
# peak-rpm
# 4150.0          5.0   95.000000
# 4200.0          5.0   88.000000
# 4250.0          3.0  121.000000
# 4350.0          4.0  123.000000
# 4400.0          3.0   76.000000
# 4500.0          7.0   98.428571
# 4650.0          1.0   64.000000
# 4750.0          4.0  165.500000
# 4800.0         36.0   81.361111
# 4900.0          1.0   69.000000

# %%
#distribution of categorical variables
gp_make_price = automobile_df.groupby(['make','body-style']).agg({'price':[np.size,np.mean]})
gp_make_price.head(10)
# Out:
#                         price
#                          size          mean
# make        body-style
# alfa-romero convertible   2.0  14997.500000
#             hatchback     1.0  16500.000000
# audi        hatchback     1.0  10198.000000
#             sedan         5.0  17647.000000
#             wagon         1.0  18920.000000
# bmw         sedan         8.0  17430.030488
# chevrolet   hatchback     2.0   9721.707317
#             sedan         1.0   6575.000000
# dodge       hatchback     5.0   7819.800000
#             sedan         3.0   7619.666667

# %%
grp_size_comp_ratio = automobile_df.groupby('engine-size').agg({'stroke':[np.size,np.mean]})
grp_size_comp_ratio.head(10)
# Out:
#             stroke
#               size      mean
# engine-size
# 61.0           1.0  3.030000
# 70.0           3.0  3.290000
# 79.0           1.0  3.070000
# 80.0           1.0  3.290000
# 90.0          12.0  3.190000
# 91.0           5.0  3.150000
# 92.0          15.0  3.222000
# 97.0          14.0  3.321429
# 98.0          14.0  3.154286
# 103.0          1.0  3.470000

# %%
correlation = automobile_df.corr()

# %%
correlation
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.398698   -0.183089 -0.310404
# normalized-losses   0.398698           1.000000   -0.165739 -0.034756
# wheel-base         -0.183089          -0.165739    1.000000  0.692655
# length             -0.310404          -0.034756    0.692655  1.000000
# width              -0.112237          -0.055081    0.716075  0.739538
# height             -0.541038          -0.313489    0.333188  0.462780
# curb-weight        -0.227691          -0.060516    0.550348  0.804493
# engine-size        -0.133309          -0.101031    0.543763  0.623994
# bore               -0.132563          -0.150221    0.527788  0.564576
# stroke             -0.072088           0.035865    0.273620  0.148597
# compression-ratio  -0.024208           0.177209    0.069047  0.245171
# horsepower         -0.007363           0.026057    0.401755  0.608132
# ...

# %%
nl = pd.crosstab(index=automobile_df["peak-rpm"],columns="horsepower")
nl
# Out:
# col_0        horsepower
# peak-rpm
# 4150.000000           5
# 4200.000000           5
# 4250.000000           3
# 4350.000000           4
# 4400.000000           3
# 4500.000000           7
# 4650.000000           1
# 4750.000000           4
# 4800.000000          36
# 4900.000000           1
# 5000.000000          27
# 5100.000000           3
# 5126.097561           2
# 5200.000000          25
# 5250.000000           7
# 5300.000000           1
# 5400.000000          13
# 5500.000000          37
# 5600.000000           1
# 5750.000000           1
# 5800.000000           7
# 5900.000000           3
# 6000.000000           9

# %%
automobile_df['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# honda            13
# mitsubishi       13
# subaru           12
# volkswagen       12
# volvo            11
# peugot           11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# chevrolet         3
# jaguar            3
# alfa-romero       3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
sns.jointplot(x="price", y="curb-weight", data=automobile_df, kind = 'kde')

# %%
plt.figure(figsize=(8,5))
automobile_df['make'].value_counts().plot(kind='bar',color='purple')
plt.title("Body Style histogram")
plt.xlabel('Make')
plt.ylabel('Body-style');

# %%
plt.figure(figsize=(8,5))
automobile_df.groupby('num-of-cylinders')['engine-location'].value_counts().plot(kind='bar', color = 'peru')
plt.title("No of Cylinders , Engine Location Analysis ")
plt.ylabel('num of cylinders')
plt.xlabel('engine location')
# Out:
# Text(0.5, 0, 'engine location')

# %%
plt.figure(figsize=(8,5))
automobile_df['engine-size'].hist(bins=5,color='brown');
plt.title("Engine Size  histogram")
plt.ylabel('Number of vehicles')
plt.xlabel('Engine Size');

# %%
plt.figure(figsize=(8,5))
automobile_df['fuel-type'].value_counts().plot(kind='bar',color='purple')
plt.title("Fuel type frequence diagram")
plt.ylabel('Number of vehicles')
plt.xlabel('Fuel type');

# %%
plt.figure(figsize=(8,5))
automobile_df['aspiration'].value_counts().plot(kind='bar',color='grey')
plt.title("Aspiration diagram")
plt.ylabel('Number of vehicles')
plt.xlabel('aspiration');

# %%
plt.figure(figsize=(8,5))
automobile_df['normalized-losses'].hist(bins=4,color='red');
plt.title("Normalized losses of vehicles")
plt.ylabel('Number of vehicles')
plt.xlabel('Normalized losses');

# %%
plt.figure(figsize=(8,5))
automobile_df['symboling'].hist(bins=4,color='magenta');
plt.title("Insurance risk ratings of vehicles")
plt.ylabel('Number of vehicles')
plt.xlabel('Risk rating');

# %%
plt.rcParams['figure.figsize']=(15,8)
ax = sns.boxplot(x="normalized-losses", y ="peak-rpm", data = automobile_df)

# %%
plt.rcParams['figure.figsize']=(23,10)
ax = sns.boxplot(x="fuel-type", y="price", data=automobile_df)

# %%
plt.rcParams['figure.figsize']=(23,10)
ax = sns.boxplot(x="curb-weight", y="drive-wheels", data=automobile_df)

# %%
g = sns.lmplot('price',"engine-size", automobile_df, hue="make", fit_reg=False)

# %%
g = sns.lmplot('curb-weight',"engine-size", automobile_df, hue="make", fit_reg=False);

# %%
g = sns.lmplot('length',"curb-weight", automobile_df, hue="make",fit_reg=False);

# %%
plt.rcParams['figure.figsize']=(10,5)
pd.pivot_table(automobile_df,index=['horsepower','num-of-cylinders'], values='highway-mpg').plot(kind='bar',color = 'rgb')
plt.title("Horsepower , cylinders Vs Milege")
plt.ylabel('highway mpg')
plt.xlabel('horsepower, cylinders')
# Out:
# Text(0.5, 0, 'horsepower, cylinders')

# %%
plt.rcParams['figure.figsize']=(8,5)
pd.pivot_table(automobile_df,index=['make','fuel-type'], values='highway-mpg').plot(kind='bar',color = 'cyan')
plt.title("Gas/ Diesel Milege")
plt.ylabel('highway mpg')
plt.xlabel('Gas/Diesel variant')
# Out:
# Text(0.5, 0, 'Gas/Diesel variant')

# %%
plt.rcParams['figure.figsize']=(10,5)
ax = sns.boxplot(x="drive-wheels", y="price", data=automobile_df)

# %%
plt.rcParams['figure.figsize']=(8,5)
pd.pivot_table(automobile_df,index=['make','drive-wheels','engine-location'], values='price').plot(kind='bar',color='purple')
plt.title("Price based on make drive wheels and engine location")
plt.ylabel('price')
plt.xlabel('Make, Drive Wheels, engine loc');

# %%
pd.pivot_table(automobile_df,index=['stroke','aspiration','fuel-type'], values='city-mpg').plot(kind='bar',color='orange')
plt.title("Combustion of Engine")
plt.ylabel('city-mpg')
plt.xlabel('Combustion ');

# %%
pd.pivot_table(automobile_df,index=['body-style','num-of-doors'], values='normalized-losses').plot(kind='bar',color='pink')
plt.title("Normalized losses based on body style and no. of doors")
plt.ylabel('Normalized losses')
plt.xlabel('Body style and No. of doors');

# %%
plt.rcParams['figure.figsize']=(8,5)
sns.regplot(clean_df["price"],clean_df["horsepower"] )

# %%
plt.figure(figsize=(8,5))
automobile_df['num-of-cylinders'].value_counts().plot(kind='bar',color='purple')
plt.ylabel('engine location')
plt.xlabel('num of cylinders')
# Out:
# Text(0.5, 0, 'num of cylinders')

# %%
d=automobile_df.corr()
plt.figure(figsize=(13,7))
a = sns.heatmap(d, cmap="Accent_r",  annot= True)
a.Title = 'Automobile attributes - Heatmap';
rotx = a.set_xticklabels(a.get_xticklabels(), rotation=45)
roty = a.set_yticklabels(a.get_yticklabels(), rotation=45)
plt.show()
